# %%
import argparse, importlib, cv2, csv, os, numpy as np

from os.path import join
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.transforms import ToTensor, Normalize, Compose
import torchsummary

from utils import tool_box as T

device = torch.device('cuda' if torch.cuda.is_available()  else 'cpu')

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser(description='Argparse')
    parser.add_argument('--datasets_dir',   type=str)
    parser.add_argument('--csv_dir',        type=str)
    parser.add_argument('--model_name',     type=str)
    parser.add_argument('--model_pth_dir',  type=str)
    parser.add_argument('--model_pth_name', type=str)
    args = parser.parse_args()

T.seed_everything(42)

# 하이퍼파라미터 설정
dataset_dir = args.datasets_dir
csv_dir = args.csv_dir
model_name = args.model_name
model_pth_dir = args.model_pth_dir
model_pth_name = args.model_pth_name
# Out:
# usage: ipykernel_launcher.py [-h] [--datasets_dir DATASETS_DIR]
#                              [--csv_dir CSV_DIR] [--model_name MODEL_NAME]
#                              [--model_pth_dir MODEL_PTH_DIR]
#                              [--model_pth_name MODEL_PTH_NAME]
# ipykernel_launcher.py: error: unrecognized arguments: --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"40dc8dcf-0a88-4598-b019-b8f073cd2ef7" --shell=9002 --transport="tcp" --iopub=9004 --f=c:\Users\worro\AppData\Roaming\jupyter\runtime\kernel-v2-4480P5ytJ9zrrU4x.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\worro\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3386: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
T.seed_everything(42)

# 하이퍼파라미터 설정
dataset_dir = '/local_datasets/MLinP/'
csv_dir = './csv_save/'
model_name = 'UNet'
model_pth_dir = './model_save/'
model_pth_name = 'UNet'
image_output_dir = join(csv_dir, model_pth_name)


# 모델 로딩
model = importlib.import_module('.' + model_name, '.models').model
torchsummary.summary(model,input_size=(3,512,512))
T.param_check(model=model)

# 파라미터 로딩
pth_filename = join(model_pth_dir,model_pth_name + '.pth')
print(pth_filename)
model.load_state_dict(torch.load(pth_filename))
model.eval()


# 데이터셋 경로
noisy_data_path = join(dataset_dir, 'test/scan/')

if not os.path.exists(image_output_dir):
    os.makedirs(image_output_dir)

noisy_transform = Compose([
    ToTensor(),
    Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# 데이터셋 로드 및 전처리
noisy_dataset = T.TestDatastLoader(noisy_data_path, noisy_transform=noisy_transform)

# 데이터 로더 설정
noisy_loader = DataLoader(noisy_dataset, batch_size=1, shuffle=False)


# 디노이징 및 이미지 저장
for noisy_image, noisy_image_path in noisy_loader:
    noisy_image = noisy_image.to(device)
    noise = model(noisy_image)

    denoised_image = noisy_image - noise
        
    # denoised_image를 CPU로 이동하여 이미지 저장
    denoised_image = denoised_image.cpu().squeeze(0)
    denoised_image = torch.clamp(denoised_image, 0, 1)  # 이미지 값을 0과 1 사이로 클램핑
    denoised_image = transforms.ToPILImage()(denoised_image)

    # Save denoised image
    output_filename = noisy_image_path[0]
    denoised_filename = join(image_output_dir , output_filename.replace('\\', '/').split('/')[-1][:-4] + '.png')
    print_format = cv2.cvtColor(np.array(denoised_image), cv2.COLOR_BGR2RGB)
    cv2.imwrite(denoised_filename, print_format)

    print(f'Saved denoised image: {denoised_filename}')

# CSV 파일 생성

output_file = join(csv_dir ,model_pth_name+'.csv')

# 폴더 내 이미지 파일 이름 목록을 가져오기
file_names = os.listdir(image_output_dir)
file_names.sort()

# CSV 파일을 작성하기 위해 오픈
with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Image File', 'Y Channel Value'])

    for file_name in file_names:
        # 이미지 로드
        image_path = os.path.join(image_output_dir, file_name)
        image = cv2.imread(image_path)

        # 이미지를 YUV 색 공간으로 변환
        image_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)

        # Y 채널 추출
        y_channel = image_yuv[:, :, 0]

        # Y 채널을 1차원 배열로 변환
        y_values = np.mean(y_channel.flatten())

        print(y_values)

        # 파일 이름과 Y 채널 값을 CSV 파일에 작성
        writer.writerow([file_name[:-4], y_values])

    print('CSV file created successfully.')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 512, 512]             896
#        BatchNorm2d-2         [-1, 32, 512, 512]              64
#               ReLU-3         [-1, 32, 512, 512]               0
#             Conv2d-4         [-1, 32, 512, 512]           9,248
#        BatchNorm2d-5         [-1, 32, 512, 512]              64
#               ReLU-6         [-1, 32, 512, 512]               0
#          MaxPool2d-7         [-1, 32, 256, 256]               0
#             Conv2d-8         [-1, 64, 256, 256]          18,496
#        BatchNorm2d-9         [-1, 64, 256, 256]             128
#              ReLU-10         [-1, 64, 256, 256]               0
#            Conv2d-11         [-1, 64, 256, 256]          36,928
#       BatchNorm2d-12         [-1, 64, 256, 256]             128
#              ReLU-13         [-1, 64, 256, 256]               0
#         MaxPool2d-14         [-1, 64, 128, 128]               0
#            Conv2d-15        [-1, 128, 128, 128]          73,856
#       BatchNorm2d-16        [-1, 128, 128, 128]             256
#              ReLU-17        [-1, 128, 128, 128]               0
#            Conv2d-18        [-1, 128, 128, 128]         147,584
#       BatchNorm2d-19        [-1, 128, 128, 128]             256
#              ReLU-20        [-1, 128, 128, 128]               0
#         MaxPool2d-21          [-1, 128, 64, 64]               0
#            Conv2d-22          [-1, 256, 64, 64]         295,168
#       BatchNorm2d-23          [-1, 256, 64, 64]             512
#              ReLU-24          [-1, 256, 64, 64]               0
#            Conv2d-25          [-1, 256, 64, 64]         590,080
#       BatchNorm2d-26          [-1, 256, 64, 64]             512
#              ReLU-27          [-1, 256, 64, 64]               0
#         MaxPool2d-28          [-1, 256, 32, 32]               0
#            Conv2d-29          [-1, 512, 32, 32]       1,180,160
#       BatchNorm2d-30          [-1, 512, 32, 32]           1,024
#              ReLU-31          [-1, 512, 32, 32]               0
#            Conv2d-32          [-1, 256, 32, 32]       1,179,904
#       BatchNorm2d-33          [-1, 256, 32, 32]             512
#              ReLU-34          [-1, 256, 32, 32]               0
#   ConvTranspose2d-35          [-1, 256, 64, 64]         262,400
#            Conv2d-36          [-1, 256, 64, 64]       1,179,904
#       BatchNorm2d-37          [-1, 256, 64, 64]             512
#              ReLU-38          [-1, 256, 64, 64]               0
#            Conv2d-39          [-1, 128, 64, 64]         295,040
#       BatchNorm2d-40          [-1, 128, 64, 64]             256
#              ReLU-41          [-1, 128, 64, 64]               0
#   ConvTranspose2d-42        [-1, 128, 128, 128]          65,664
#            Conv2d-43        [-1, 128, 128, 128]         295,040
#       BatchNorm2d-44        [-1, 128, 128, 128]             256
#              ReLU-45        [-1, 128, 128, 128]               0
#            Conv2d-46         [-1, 64, 128, 128]          73,792
#       BatchNorm2d-47         [-1, 64, 128, 128]             128
#              ReLU-48         [-1, 64, 128, 128]               0
#   ConvTranspose2d-49         [-1, 64, 256, 256]          16,448
#            Conv2d-50         [-1, 64, 256, 256]          73,792
#       BatchNorm2d-51         [-1, 64, 256, 256]             128
#              ReLU-52         [-1, 64, 256, 256]               0
#            Conv2d-53         [-1, 32, 256, 256]          18,464
#       BatchNorm2d-54         [-1, 32, 256, 256]              64
#              ReLU-55         [-1, 32, 256, 256]               0
#   ConvTranspose2d-56         [-1, 32, 512, 512]           4,128
#            Conv2d-57         [-1, 32, 512, 512]          18,464
#       BatchNorm2d-58         [-1, 32, 512, 512]              64
#              ReLU-59         [-1, 32, 512, 512]               0
#            Conv2d-60         [-1, 16, 512, 512]           4,624
#       BatchNorm2d-61         [-1, 16, 512, 512]              32
#              ReLU-62         [-1, 16, 512, 512]               0
#            Conv2d-63          [-1, 3, 512, 512]              51
# ================================================================
# Total params: 5,845,027
# Trainable params: 5,845,027
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.00
# Forward/backward pass size (MB): 1434.00
# Params size (MB): 22.30
# Estimated Total Size (MB): 1459.30
# ----------------------------------------------------------------
# Number of parameters: 5845027
# @@@@@@@@@@@@@ IT IS LOWER THAN 10 MILLIONS 4154973 PARAMETERS LEFT@@@@@@@@@@@@@
# ./model_save/UNet.pth
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00016.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00019.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00053.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00054.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00055.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00085.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00120.02.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00123.02.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00150.01.png
# Saved denoised image: ./csv_save/UNet.pth\BookOfMaking.00159.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00013.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00018.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00019.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00034.02.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00050.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00100.02.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00114.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00115.01.png
# Saved denoised image: ./csv_save/UNet.pth\BuildYourOwnFirstPersonShooterInUnity.00139.02.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00045.01.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00071.02.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00072.01.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00117.01.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00121.02.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00143.02.png
# Saved denoised image: ./csv_save/UNet.pth\CreateGraphicalUserInterfacesWithPython.00152.01.png
# Saved denoised image: ./csv_save/UNet.pth\EssentialsAIYProjectsVoice.00005.02.png
# Saved denoised image: ./csv_save/UNet.pth\EssentialsAIYProjectsVoice.00015.01.png
# Saved denoised image: ./csv_save/UNet.pth\EssentialsAIYProjectsVoice.00028.02.png
# Saved denoised image: ./csv_save/UNet.pth\EssentialsAIYProjectsVoice.00058.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00006.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00011.01.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00015.01.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00048.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00049.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00074.01.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00083.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00108.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00113.01.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedArduino.00114.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedMicroPython.00106.02.png
# Saved denoised image: ./csv_save/UNet.pth\GetStartedMicroPython.00137.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace36.00015.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace36.00023.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace36.00052.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace36.00056.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace36.00115.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace37.00005.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace37.00029.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace37.00070.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace37.00072.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace37.00099.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace37.00102.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace38.00063.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace38.00069.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace38.00084.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace38.00105.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace40.00013.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace40.00056.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace40.00081.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace40.00097.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00013.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00034.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00060.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00070.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00087.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00087.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace41.00113.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace42.00023.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace42.00025.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace42.00042.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace42.00100.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace43.00028.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace43.00057.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace44.00024.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace44.00101.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace44.00110.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00006.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00007.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00009.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00026.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00044.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00047.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00051.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00056.02.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace45.00062.01.png
# Saved denoised image: ./csv_save/UNet.pth\HackSpace46.00029.01.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiBeginnersGuide4thEdition.00082.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiBeginnersGuide4thEdition.00148.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiBeginnersGuide4thEdition.00172.01.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiBeginnersGuide4thEdition.00193.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiBeginnersGuide4thEdition.00215.01.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiCameraGuide.00017.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiCameraGuide.00024.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiCameraGuide.00051.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiCameraGuide.00073.02.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiCameraGuide.00081.01.png
# Saved denoised image: ./csv_save/UNet.pth\RaspberryPiCameraGuide.00083.02.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_003.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_045.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_054.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_070.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_100.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_146.png
# Saved denoised image: ./csv_save/UNet.pth\scanner01_161.png
# Saved denoised image: ./csv_save/UNet.pth\scanner02_001.png
# Saved denoised image: ./csv_save/UNet.pth\scanner02_061.png
# Saved denoised image: ./csv_save/UNet.pth\scanner02_063.png
# Saved denoised image: ./csv_save/UNet.pth\scanner02_137.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_052.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_084.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_106.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_115.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_131.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_142.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_156.png
# Saved denoised image: ./csv_save/UNet.pth\scanner03_179.png
# Saved denoised image: ./csv_save/UNet.pth\scanner04_007.png
# Saved denoised image: ./csv_save/UNet.pth\scanner04_013.png
# Saved denoised image: ./csv_save/UNet.pth\scanner04_015.png
# Saved denoised image: ./csv_save/UNet.pth\scanner04_037.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00071.01.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00073.01.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00088.01.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00135.02.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00140.02.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00141.02.png
# Saved denoised image: ./csv_save/UNet.pth\TheOfficialRaspberryPiHandbook2022.00167.02.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00004.02.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00046.01.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00052.01.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00074.01.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00110.02.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00118.01.png
# Saved denoised image: ./csv_save/UNet.pth\WearableTechProjects.00153.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe46.00023.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe46.00076.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe46.00080.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe46.00092.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe46.00116.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00006.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00009.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00011.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00032.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00034.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00054.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00102.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe47.00113.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00045.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00048.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00070.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00075.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00077.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00082.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00086.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00092.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe48.00100.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00007.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00017.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00044.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00086.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00111.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00113.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe50.00116.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe51.00021.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe51.00047.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe51.00049.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe51.00057.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe51.00067.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe51.00084.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00015.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00035.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00037.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00046.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00057.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00063.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00066.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00070.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00086.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe53.00102.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe56.00003.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe56.00007.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe56.00024.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe56.00049.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe56.00067.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe56.00108.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe57.00016.02.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe57.00063.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe57.00065.01.png
# Saved denoised image: ./csv_save/UNet.pth\Wireframe57.00090.01.png
# ./csv_save/UNet.pth.csv
# 194.9037208557129
# 190.85516738891602
# 190.68960571289062
# 154.32666778564453
# 116.22393035888672
# 84.68420028686523
# 137.85559844970703
# 167.25569534301758
# 150.50343704223633
# 82.77384948730469
# 237.59014129638672
# 194.2669563293457
# 224.47565841674805
# 235.60773849487305
# 199.49609756469727
# 158.37603378295898
# 134.63468170166016
# 116.71577835083008
# 86.8117790222168
# 224.27057647705078
# 236.8126983642578
# 218.14456176757812
# 241.41563034057617
# 235.9741325378418
# 227.7301788330078
# 222.80876922607422
# 140.82800674438477
# 107.83663558959961
# 80.93976211547852
# 171.164794921875
# 82.85428619384766
# 83.0877685546875
# 99.12510681152344
# 233.37386322021484
# 134.2846336364746
# 216.86835479736328
# 110.20933151245117
# 238.20131301879883
# 175.38873672485352
# 175.69275283813477
# 191.56360244750977
# 238.3531951904297
# 80.26736450195312
# 143.48108291625977
# 123.50607681274414
# 228.7027816772461
# 82.61962509155273
# 111.06767654418945
# 90.0444107055664
# 88.27776336669922
# 186.23677825927734
# 93.8460922241211
# 84.09698104858398
