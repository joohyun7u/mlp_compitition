# %% [markdown]
# # 기본 세팅

# %%
import random
import numpy as np
import cv2
import os
import torch
import torch.utils.data as data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor, Normalize, Compose
from os.path import join
from os import listdir
from torchsummary import summary
import time
import zipfile

# %%
# !gdown https://drive.google.com/uc?id=16zAeGDmqbAvn7Iy8V-mBylKx6rG-wgLD
# !gdown https://drive.google.com/uc?id=1cqxSVFxfonx5qKVIdfByOq7uYdNZY8ea
# !gdown https://drive.google.com/uc?id=1zmfrXzT9lnLg7NlQ-hXekZlyX9aGNNqj

os.makedirs('/content/dataset/train/clean')
os.makedirs('/content/dataset/train/scan')
os.makedirs('/content/dataset/test/scan')
    	
train_clean_zip = zipfile.ZipFile('/content/train_clean.zip')
train_clean_zip.extractall('/content/dataset/train/clean')
train_clean_zip.close()

train_scan_zip = zipfile.ZipFile('/content/train_scan.zip')
train_scan_zip.extractall('/content/dataset/train/scan')
train_scan_zip.close()

test_scan_zip = zipfile.ZipFile('/content/test_scan.zip')
test_scan_zip.extractall('/content/dataset/test/scan')
test_scan_zip.close()

# %%
# 랜덤 시드 고정
np.random.seed(42)

# 시작 시간 기록
start_time = time.time()

# 이미지 로드 함수 정의
def load_img(filepath):
    img = cv2.imread(filepath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %% [markdown]
# # 모델 훈련

# %%
# DnCNN 모델 정의
class DnCNN(nn.Module):
    def __init__(self, num_layers=17, num_channels=64):
        super(DnCNN, self).__init__()
        layers = [nn.Conv2d(3, num_channels, kernel_size=3, padding=1), nn.ReLU(inplace=True)]
        for _ in range(num_layers - 2):
            layers.append(nn.Conv2d(num_channels, num_channels, kernel_size=3, padding=1))
            layers.append(nn.BatchNorm2d(num_channels))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(num_channels, 3, kernel_size=3, padding=1))
        self.dncnn = nn.Sequential(*layers)

    def forward(self, x):
        out = self.dncnn(x)
        return out

# %%
# 커스텀 데이터셋 클래스 정의
class CustomDataset(data.Dataset):
    def __init__(self, noisy_image_paths, clean_image_paths, patch_size = 128, transform=None):
        self.clean_image_paths = [join(clean_image_paths, x) for x in listdir(clean_image_paths)]
        self.noisy_image_paths = [join(noisy_image_paths, x) for x in listdir(noisy_image_paths)]
        self.transform = transform
        self.patch_size = patch_size

    def __len__(self):
        return len(self.noisy_image_paths)

    def __getitem__(self, index):
        # 이미지 불러오기
        noisy_image = load_img(self.noisy_image_paths[index])
        clean_image = load_img(self.clean_image_paths[index])

        H, W, _ = clean_image.shape

        # 이미지 랜덤 크롭
        rnd_h = random.randint(0, max(0, H - self.patch_size))
        rnd_w = random.randint(0, max(0, W - self.patch_size))
        noisy_image = noisy_image[rnd_h:rnd_h + self.patch_size, rnd_w:rnd_w + self.patch_size, :]
        clean_image = clean_image[rnd_h:rnd_h + self.patch_size, rnd_w:rnd_w + self.patch_size, :]
        
        # transform 적용
        if self.transform:
            noisy_image = self.transform(noisy_image)
            clean_image = self.transform(clean_image)
        
        return noisy_image, clean_image

# %%
# 하이퍼파라미터 설정
num_epochs = 3
batch_size = 64
learning_rate = 0.001

# 데이터셋 경로
noisy_image_paths = '/content/dataset/train/scan'
clean_image_paths = '/content/dataset/train/clean'

# 데이터셋 로드 및 전처리
train_transform = Compose([
    ToTensor(),
    Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# 커스텀 데이터셋 인스턴스 생성
train_dataset = CustomDataset(noisy_image_paths, clean_image_paths, transform=train_transform)

# 데이터 로더 설정
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
# GPU 사용 여부 확인
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# DnCNN 모델 인스턴스 생성 및 GPU로 이동
model = DnCNN().to(device)
print(summary(model, (3, 128, 128)))

# 손실 함수와 최적화 알고리즘 설정
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# 모델 학습
model.train()
best_loss = 9999.0
for epoch in range(num_epochs):
    running_loss = 0.0
    for noisy_images, clean_images in train_loader:
        noisy_images = noisy_images.to(device)
        clean_images = clean_images.to(device)
        optimizer.zero_grad()
        outputs = model(noisy_images)
        loss = criterion(outputs, noisy_images-clean_images)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * noisy_images.size(0)
    epoch_loss = running_loss / len(train_dataset)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}')

# 현재 epoch의 loss가 최소 loss보다 작으면 모델 갱신
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), 'best_dncnn_model.pth')
        print(f"{epoch+1}epoch 모델 저장 완료")

# 종료 시간 기록
end_time = time.time()
# Out:
# Epoch 1/3, Loss: 0.0413
# 1epoch 모델 저장 완료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-fdaa816304e3> in <cell line: 4>()
#      12         loss.backward()
#      13         optimizer.step()
# ---> 14         running_loss += loss.item() * noisy_images.size(0)
#      15     epoch_loss = running_loss / len(train_dataset)
#      16     print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}')
#
# KeyboardInterrupt:

# %%
# 종료 시간 기록
end_time = time.time()

# 소요 시간 계산
training_time = end_time - start_time

# 시, 분, 초로 변환
minutes = int(training_time // 60)
seconds = int(training_time % 60)
hours = int(minutes // 60)
minutes = int(minutes % 60)

# 결과 출력
print(f"훈련 소요 시간: {hours}시간 {minutes}분 {seconds}초")
# Out:
# 훈련 소요 시간: 0시간 10분 14초

# %% [markdown]
# # 모델 테스트 (추론)

# %%
import os
from os import listdir
from os.path import join, splitext
import cv2
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Normalize, Compose

# 랜덤 시드 고정
np.random.seed(42)

def load_img(filepath):
    img = cv2.imread(filepath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# DnCNN 모델 정의
class DnCNN(nn.Module):
    def __init__(self, num_layers=17, num_channels=64):
        super(DnCNN, self).__init__()
        layers = [nn.Conv2d(3, num_channels, kernel_size=3, padding=1), nn.ReLU(inplace=True)]
        for _ in range(num_layers - 2):
            layers.append(nn.Conv2d(num_channels, num_channels, kernel_size=3, padding=1))
            layers.append(nn.BatchNorm2d(num_channels))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(num_channels, 3, kernel_size=3, padding=1))
        self.dncnn = nn.Sequential(*layers)

    def forward(self, x):
        out = self.dncnn(x)
        return out

model = DnCNN()
model.load_state_dict(torch.load('best_dncnn_model.pth'))
model.eval()

# GPU 사용 여부 확인
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# 데이터셋 경로
noisy_data_path = '/content/dataset/test/scan'
output_path = '/content/output'

if not os.path.exists(output_path):
    os.makedirs(output_path)

class CustomDatasetTest(data.Dataset):
    def __init__(self, noisy_image_paths, transform=None):
        self.noisy_image_paths = [join(noisy_image_paths, x) for x in listdir(noisy_image_paths)]
        self.transform = transform

    def __len__(self):
        return len(self.noisy_image_paths)

    def __getitem__(self, index):
        
        noisy_image_path = self.noisy_image_paths[index]
        noisy_image = load_img(self.noisy_image_paths[index])
        
        if self.transform:
            noisy_image = self.transform(noisy_image)

        return noisy_image, noisy_image_path

test_transform = Compose([
    ToTensor(),
    Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# 데이터셋 로드 및 전처리
noisy_dataset = CustomDatasetTest(noisy_data_path, transform=test_transform)

# 데이터 로더 설정
noisy_loader = DataLoader(noisy_dataset, batch_size=1, shuffle=False)

# 이미지 denoising 및 저장
for noisy_image, noisy_image_path in noisy_loader:
    noisy_image = noisy_image.to(device)
    noise = model(noisy_image)

    denoised_image = noisy_image - noise
    
    # denoised_image를 CPU로 이동하여 이미지 저장
    denoised_image = denoised_image.cpu().squeeze(0)
    denoised_image = torch.clamp(denoised_image, 0, 1)  # 이미지 값을 0과 1 사이로 클램핑
    denoised_image = transforms.ToPILImage()(denoised_image)

    # Save denoised image
    output_filename = noisy_image_path[0]
    denoised_filename = output_path + '/' + output_filename.split('/')[-1][:-4] + '.png'
    denoised_image.save(denoised_filename) 
    
    print(f'Saved denoised image: {denoised_filename}')
# Out:
# Saved denoised image: /content/output/MagPi094.00011.01.png
# Saved denoised image: /content/output/MagPi101.00009.02.png
# Saved denoised image: /content/output/MagPi068.00064.02.png
# Saved denoised image: /content/output/Wireframe56.00067.01.png
# Saved denoised image: /content/output/MagPi060.00042.01.png
# Saved denoised image: /content/output/HackSpace37.00102.02.png
# Saved denoised image: /content/output/MagPi066.00064.01.png
# Saved denoised image: /content/output/HackSpace36.00056.02.png
# Saved denoised image: /content/output/MagPi050.00018.01.png
# Saved denoised image: /content/output/MagPi093.00004.02.png
# Saved denoised image: /content/output/Wireframe46.00092.02.png
# Saved denoised image: /content/output/MagPi047.00044.01.png
# Saved denoised image: /content/output/RaspberryPiCameraGuide.00073.02.png
# Saved denoised image: /content/output/Wireframe53.00063.01.png
# Saved denoised image: /content/output/MagPi104.00083.02.png
# Saved denoised image: /content/output/HackSpace42.00025.01.png
# Saved denoised image: /content/output/Wireframe46.00116.02.png
# Saved denoised image: /content/output/Wireframe53.00066.01.png
# Saved denoised image: /content/output/MagPi071.00053.01.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00013.01.png
# Saved denoised image: /content/output/HackSpace36.00023.02.png
# Saved denoised image: /content/output/MagPi058.00041.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00140.02.png
# Saved denoised image: /content/output/MagPi099.00017.01.png
# Saved denoised image: /content/output/scanner01_100.png
# Saved denoised image: /content/output/MagPi076.00080.02.png
# Saved denoised image: /content/output/MagPi079.00011.02.png
# Saved denoised image: /content/output/MagPi062.00077.01.png
# Saved denoised image: /content/output/WearableTechProjects.00074.01.png
# Saved denoised image: /content/output/MagPi064.00055.01.png
# Saved denoised image: /content/output/MagPi060.00022.01.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00115.01.png
# Saved denoised image: /content/output/HackSpace46.00029.01.png
# Saved denoised image: /content/output/MagPi089.00089.02.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00143.02.png
# Saved denoised image: /content/output/GetStartedMicroPython.00106.02.png
# Saved denoised image: /content/output/MagPi064.00050.01.png
# Saved denoised image: /content/output/MagPi098.00095.01.png
# Saved denoised image: /content/output/HackSpace47.00044.01.png
# Saved denoised image: /content/output/MagPi075.00087.02.png
# Saved denoised image: /content/output/HackSpace51.00071.01.png
# Saved denoised image: /content/output/MagPi073.00061.02.png
# Saved denoised image: /content/output/HackSpace50.00062.01.png
# Saved denoised image: /content/output/MagPi067.00073.01.png
# Saved denoised image: /content/output/scanner03_142.png
# Saved denoised image: /content/output/MagPi060.00069.02.png
# Saved denoised image: /content/output/scanner02_137.png
# Saved denoised image: /content/output/MagPi092.00028.02.png
# Saved denoised image: /content/output/MagPi096.00094.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00088.01.png
# Saved denoised image: /content/output/MagPi086.00071.02.png
# Saved denoised image: /content/output/MagPi072.00074.02.png
# Saved denoised image: /content/output/MagPi095.00007.01.png
# Saved denoised image: /content/output/WearableTechProjects.00052.01.png
# Saved denoised image: /content/output/HackSpace43.00028.02.png
# Saved denoised image: /content/output/Wireframe48.00048.02.png
# Saved denoised image: /content/output/Wireframe57.00090.01.png
# Saved denoised image: /content/output/MagPi100.00066.02.png
# Saved denoised image: /content/output/MagPi059.00059.01.png
# Saved denoised image: /content/output/MagPi098.00085.01.png
# Saved denoised image: /content/output/MagPi079.00032.02.png
# Saved denoised image: /content/output/MagPi061.00091.02.png
# Saved denoised image: /content/output/GetStartedArduino.00049.02.png
# Saved denoised image: /content/output/MagPi093.00060.01.png
# Saved denoised image: /content/output/MagPi049.00045.01.png
# Saved denoised image: /content/output/WearableTechProjects.00110.02.png
# Saved denoised image: /content/output/MagPi096.00089.02.png
# Saved denoised image: /content/output/MagPi107.00012.02.png
# Saved denoised image: /content/output/MagPi073.00021.01.png
# Saved denoised image: /content/output/Wireframe57.00065.01.png
# Saved denoised image: /content/output/Wireframe48.00077.02.png
# Saved denoised image: /content/output/HackSpace45.00007.01.png
# Saved denoised image: /content/output/MagPi066.00073.01.png
# Saved denoised image: /content/output/MagPi057.00057.01.png
# Saved denoised image: /content/output/MagPi072.00021.01.png
# Saved denoised image: /content/output/MagPi092.00062.02.png
# Saved denoised image: /content/output/GetStartedArduino.00048.02.png
# Saved denoised image: /content/output/scanner01_003.png
# Saved denoised image: /content/output/GetStartedArduino.00006.02.png
# Saved denoised image: /content/output/BookOfMaking.00055.01.png
# Saved denoised image: /content/output/MagPi101.00050.02.png
# Saved denoised image: /content/output/BookOfMaking.00085.01.png
# Saved denoised image: /content/output/HackSpace46.00034.01.png
# Saved denoised image: /content/output/scanner03_084.png
# Saved denoised image: /content/output/MagPi049.00091.01.png
# Saved denoised image: /content/output/MagPi096.00089.01.png
# Saved denoised image: /content/output/MagPi089.00083.02.png
# Saved denoised image: /content/output/MagPi063.00007.01.png
# Saved denoised image: /content/output/scanner04_007.png
# Saved denoised image: /content/output/MagPi096.00044.02.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00050.01.png
# Saved denoised image: /content/output/MagPi074.00079.01.png
# Saved denoised image: /content/output/HackSpace45.00051.02.png
# Saved denoised image: /content/output/MagPi112.00031.02.png
# Saved denoised image: /content/output/MagPi095.00055.01.png
# Saved denoised image: /content/output/MagPi077.00083.02.png
# Saved denoised image: /content/output/MagPi057.00034.01.png
# Saved denoised image: /content/output/Wireframe46.00023.02.png
# Saved denoised image: /content/output/RaspberryPiCameraGuide.00051.02.png
# Saved denoised image: /content/output/GetStartedArduino.00114.02.png
# Saved denoised image: /content/output/HackSpace45.00047.01.png
# Saved denoised image: /content/output/HackSpace40.00097.01.png
# Saved denoised image: /content/output/MagPi064.00098.01.png
# Saved denoised image: /content/output/MagPi097.00021.02.png
# Saved denoised image: /content/output/MagPi071.00047.01.png
# Saved denoised image: /content/output/MagPi062.00099.02.png
# Saved denoised image: /content/output/MagPi112.00017.02.png
# Saved denoised image: /content/output/Wireframe53.00035.02.png
# Saved denoised image: /content/output/HackSpace42.00100.01.png
# Saved denoised image: /content/output/HackSpace40.00056.02.png
# Saved denoised image: /content/output/MagPi071.00046.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00071.01.png
# Saved denoised image: /content/output/MagPi100.00074.01.png
# Saved denoised image: /content/output/MagPi071.00090.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00135.02.png
# Saved denoised image: /content/output/WearableTechProjects.00118.01.png
# Saved denoised image: /content/output/Wireframe50.00086.01.png
# Saved denoised image: /content/output/MagPi103.00046.01.png
# Saved denoised image: /content/output/MagPi051.00082.02.png
# Saved denoised image: /content/output/Wireframe47.00009.01.png
# Saved denoised image: /content/output/BookOfMaking.00019.01.png
# Saved denoised image: /content/output/scanner03_052.png
# Saved denoised image: /content/output/HackSpace45.00006.02.png
# Saved denoised image: /content/output/EssentialsAIYProjectsVoice.00015.01.png
# Saved denoised image: /content/output/MagPi051.00010.01.png
# Saved denoised image: /content/output/MagPi051.00053.02.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00121.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00073.01.png
# Saved denoised image: /content/output/MagPi106.00072.01.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00034.02.png
# Saved denoised image: /content/output/Wireframe46.00076.01.png
# Saved denoised image: /content/output/MagPi060.00056.02.png
# Saved denoised image: /content/output/MagPi091.00082.01.png
# Saved denoised image: /content/output/MagPi064.00062.01.png
# Saved denoised image: /content/output/MagPi099.00022.01.png
# Saved denoised image: /content/output/MagPi096.00035.01.png
# Saved denoised image: /content/output/MagPi112.00006.01.png
# Saved denoised image: /content/output/MagPi105.00071.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00167.02.png
# Saved denoised image: /content/output/Wireframe50.00116.02.png
# Saved denoised image: /content/output/Wireframe47.00034.02.png
# Saved denoised image: /content/output/MagPi099.00039.02.png
# Saved denoised image: /content/output/MagPi112.00084.02.png
# Saved denoised image: /content/output/Wireframe53.00102.01.png
# Saved denoised image: /content/output/MagPi089.00066.01.png
# Saved denoised image: /content/output/MagPi072.00072.02.png
# Saved denoised image: /content/output/HackSpace41.00034.01.png
# Saved denoised image: /content/output/MagPi104.00030.01.png
# Saved denoised image: /content/output/MagPi098.00022.02.png
# Saved denoised image: /content/output/Wireframe48.00045.01.png
# Saved denoised image: /content/output/Wireframe51.00057.01.png
# Saved denoised image: /content/output/MagPi075.00059.02.png
# Saved denoised image: /content/output/MagPi096.00090.02.png
# Saved denoised image: /content/output/HackSpace51.00071.02.png
# Saved denoised image: /content/output/MagPi066.00033.02.png
# Saved denoised image: /content/output/HackSpace37.00070.02.png
# Saved denoised image: /content/output/MagPi063.00054.02.png
# Saved denoised image: /content/output/MagPi063.00037.02.png
# Saved denoised image: /content/output/scanner02_001.png
# Saved denoised image: /content/output/MagPi105.00043.02.png
# Saved denoised image: /content/output/HackSpace37.00029.02.png
# Saved denoised image: /content/output/MagPi071.00065.02.png
# Saved denoised image: /content/output/MagPi103.00014.02.png
# Saved denoised image: /content/output/MagPi047.00054.01.png
# Saved denoised image: /content/output/HackSpace47.00004.01.png
# Saved denoised image: /content/output/MagPi070.00041.01.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00082.02.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00117.01.png
# Saved denoised image: /content/output/HackSpace51.00023.01.png
# Saved denoised image: /content/output/MagPi047.00028.01.png
# Saved denoised image: /content/output/scanner03_179.png
# Saved denoised image: /content/output/MagPi097.00078.02.png
# Saved denoised image: /content/output/MagPi106.00010.02.png
# Saved denoised image: /content/output/Wireframe48.00070.01.png
# Saved denoised image: /content/output/Wireframe53.00015.01.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00065.01.png
# Saved denoised image: /content/output/MagPi066.00057.02.png
# Saved denoised image: /content/output/MagPi108.00071.01.png
# Saved denoised image: /content/output/MagPi093.00080.01.png
# Saved denoised image: /content/output/HackSpace41.00060.01.png
# Saved denoised image: /content/output/Wireframe50.00111.01.png
# Saved denoised image: /content/output/MagPi051.00026.02.png
# Saved denoised image: /content/output/MagPi056.00089.02.png
# Saved denoised image: /content/output/MagPi075.00086.01.png
# Saved denoised image: /content/output/HackSpace37.00072.02.png
# Saved denoised image: /content/output/MagPi052.00016.01.png
# Saved denoised image: /content/output/GetStartedArduino.00108.02.png
# Saved denoised image: /content/output/HackSpace51.00033.02.png
# Saved denoised image: /content/output/MagPi052.00003.01.png
# Saved denoised image: /content/output/MagPi097.00013.02.png
# Saved denoised image: /content/output/MagPi112.00072.02.png
# Saved denoised image: /content/output/MagPi056.00079.01.png
# Saved denoised image: /content/output/MagPi091.00023.01.png
# Saved denoised image: /content/output/MagPi047.00096.01.png
# Saved denoised image: /content/output/MagPi113.00070.02.png
# Saved denoised image: /content/output/scanner01_070.png
# Saved denoised image: /content/output/HackSpace37.00005.01.png
# Saved denoised image: /content/output/MagPi079.00052.02.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00148.02.png
# Saved denoised image: /content/output/scanner02_063.png
# Saved denoised image: /content/output/MagPi050.00095.02.png
# Saved denoised image: /content/output/MagPi110.00034.02.png
# Saved denoised image: /content/output/MagPi058.00082.02.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00072.01.png
# Saved denoised image: /content/output/MagPi067.00006.02.png
# Saved denoised image: /content/output/MagPi058.00031.02.png
# Saved denoised image: /content/output/EssentialsAIYProjectsVoice.00058.02.png
# Saved denoised image: /content/output/MagPi100.00090.01.png
# Saved denoised image: /content/output/MagPi065.00047.01.png
# Saved denoised image: /content/output/Wireframe50.00007.02.png
# Saved denoised image: /content/output/GetStartedArduino.00015.01.png
# Saved denoised image: /content/output/MagPi104.00098.01.png
# Saved denoised image: /content/output/MagPi076.00043.02.png
# Saved denoised image: /content/output/scanner03_106.png
# Saved denoised image: /content/output/MagPi074.00026.01.png
# Saved denoised image: /content/output/MagPi101.00007.01.png
# Saved denoised image: /content/output/MagPi070.00100.02.png
# Saved denoised image: /content/output/MagPi079.00015.02.png
# Saved denoised image: /content/output/MagPi095.00069.01.png
# Saved denoised image: /content/output/MagPi058.00089.01.png
# Saved denoised image: /content/output/MagPi094.00071.02.png
# Saved denoised image: /content/output/RaspberryPiCameraGuide.00081.01.png
# Saved denoised image: /content/output/MagPi091.00003.01.png
# Saved denoised image: /content/output/scanner03_115.png
# Saved denoised image: /content/output/MagPi066.00074.01.png
# Saved denoised image: /content/output/MagPi095.00080.02.png
# Saved denoised image: /content/output/MagPi072.00097.01.png
# Saved denoised image: /content/output/MagPi056.00079.02.png
# Saved denoised image: /content/output/MagPi110.00013.01.png
# Saved denoised image: /content/output/MagPi074.00064.01.png
# Saved denoised image: /content/output/MagPi095.00030.01.png
# Saved denoised image: /content/output/Wireframe47.00032.01.png
# Saved denoised image: /content/output/MagPi108.00044.01.png
# Saved denoised image: /content/output/MagPi100.00027.02.png
# Saved denoised image: /content/output/MagPi063.00075.02.png
# Saved denoised image: /content/output/MagPi112.00082.01.png
# Saved denoised image: /content/output/MagPi091.00079.01.png
# Saved denoised image: /content/output/MagPi051.00097.01.png
# Saved denoised image: /content/output/MagPi050.00064.01.png
# Saved denoised image: /content/output/MagPi065.00057.01.png
# Saved denoised image: /content/output/MagPi096.00022.01.png
# Saved denoised image: /content/output/MagPi068.00056.02.png
# Saved denoised image: /content/output/MagPi097.00046.01.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00152.01.png
# Saved denoised image: /content/output/Wireframe53.00037.01.png
# Saved denoised image: /content/output/MagPi089.00017.01.png
# Saved denoised image: /content/output/Wireframe51.00084.02.png
# Saved denoised image: /content/output/MagPi063.00028.01.png
# Saved denoised image: /content/output/MagPi059.00078.02.png
# Saved denoised image: /content/output/MagPi100.00088.02.png
# Saved denoised image: /content/output/WearableTechProjects.00046.01.png
# Saved denoised image: /content/output/Wireframe48.00086.01.png
# Saved denoised image: /content/output/MagPi059.00095.02.png
# Saved denoised image: /content/output/Wireframe48.00092.01.png
# Saved denoised image: /content/output/MagPi095.00081.02.png
# Saved denoised image: /content/output/scanner03_131.png
# Saved denoised image: /content/output/HackSpace41.00070.01.png
# Saved denoised image: /content/output/MagPi056.00076.02.png
# Saved denoised image: /content/output/Wireframe56.00007.02.png
# Saved denoised image: /content/output/HackSpace44.00024.02.png
# Saved denoised image: /content/output/Wireframe47.00113.01.png
# Saved denoised image: /content/output/MagPi048.00047.02.png
# Saved denoised image: /content/output/MagPi098.00080.01.png
# Saved denoised image: /content/output/MagPi108.00064.01.png
# Saved denoised image: /content/output/MagPi108.00090.02.png
# Saved denoised image: /content/output/WearableTechProjects.00004.02.png
# Saved denoised image: /content/output/MagPi092.00062.01.png
# Saved denoised image: /content/output/MagPi049.00071.02.png
# Saved denoised image: /content/output/Wireframe47.00006.01.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00172.01.png
# Saved denoised image: /content/output/HackSpace47.00101.01.png
# Saved denoised image: /content/output/MagPi110.00045.02.png
# Saved denoised image: /content/output/MagPi091.00049.01.png
# Saved denoised image: /content/output/HackSpace45.00062.01.png
# Saved denoised image: /content/output/MagPi092.00058.01.png
# Saved denoised image: /content/output/MagPi050.00061.01.png
# Saved denoised image: /content/output/MagPi075.00083.02.png
# Saved denoised image: /content/output/MagPi095.00030.02.png
# Saved denoised image: /content/output/HackSpace47.00071.02.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00019.01.png
# Saved denoised image: /content/output/MagPi058.00099.01.png
# Saved denoised image: /content/output/MagPi070.00007.01.png
# Saved denoised image: /content/output/MagPi059.00034.01.png
# Saved denoised image: /content/output/MagPi105.00017.02.png
# Saved denoised image: /content/output/GetStartedArduino.00074.01.png
# Saved denoised image: /content/output/MagPi110.00012.01.png
# Saved denoised image: /content/output/HackSpace47.00044.02.png
# Saved denoised image: /content/output/scanner04_013.png
# Saved denoised image: /content/output/Wireframe48.00075.01.png
# Saved denoised image: /content/output/MagPi097.00095.02.png
# Saved denoised image: /content/output/scanner04_037.png
# Saved denoised image: /content/output/HackSpace41.00087.01.png
# Saved denoised image: /content/output/MagPi097.00022.01.png
# Saved denoised image: /content/output/MagPi112.00067.02.png
# Saved denoised image: /content/output/HackSpace47.00104.01.png
# Saved denoised image: /content/output/scanner01_045.png
# Saved denoised image: /content/output/Wireframe48.00100.02.png
# Saved denoised image: /content/output/MagPi056.00033.01.png
# Saved denoised image: /content/output/HackSpace40.00081.01.png
# Saved denoised image: /content/output/MagPi086.00007.02.png
# Saved denoised image: /content/output/HackSpace46.00106.01.png
# Saved denoised image: /content/output/MagPi095.00029.01.png
# Saved denoised image: /content/output/MagPi048.00084.02.png
# Saved denoised image: /content/output/MagPi058.00098.01.png
# Saved denoised image: /content/output/MagPi049.00036.02.png
# Saved denoised image: /content/output/MagPi052.00088.02.png
# Saved denoised image: /content/output/MagPi068.00093.02.png
# Saved denoised image: /content/output/MagPi058.00086.02.png
# Saved denoised image: /content/output/MagPi092.00034.01.png
# Saved denoised image: /content/output/HackSpace38.00105.02.png
# Saved denoised image: /content/output/MagPi093.00086.02.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00139.02.png
# Saved denoised image: /content/output/MagPi057.00055.01.png
# Saved denoised image: /content/output/MagPi094.00054.01.png
# Saved denoised image: /content/output/MagPi047.00027.01.png
# Saved denoised image: /content/output/Wireframe53.00070.01.png
# Saved denoised image: /content/output/Wireframe56.00024.02.png
# Saved denoised image: /content/output/MagPi068.00086.01.png
# Saved denoised image: /content/output/scanner02_061.png
# Saved denoised image: /content/output/HackSpace45.00044.02.png
# Saved denoised image: /content/output/MagPi048.00048.02.png
# Saved denoised image: /content/output/MagPi064.00046.02.png
# Saved denoised image: /content/output/Wireframe57.00063.01.png
# Saved denoised image: /content/output/HackSpace45.00026.02.png
# Saved denoised image: /content/output/MagPi104.00070.01.png
# Saved denoised image: /content/output/MagPi064.00071.01.png
# Saved denoised image: /content/output/MagPi092.00002.02.png
# Saved denoised image: /content/output/MagPi094.00069.02.png
# Saved denoised image: /content/output/BookOfMaking.00016.01.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00008.02.png
# Saved denoised image: /content/output/MagPi047.00031.02.png
# Saved denoised image: /content/output/MagPi092.00067.01.png
# Saved denoised image: /content/output/Wireframe51.00021.02.png
# Saved denoised image: /content/output/Wireframe46.00080.01.png
# Saved denoised image: /content/output/MagPi095.00062.02.png
# Saved denoised image: /content/output/RaspberryPiCameraGuide.00083.02.png
# Saved denoised image: /content/output/MagPi112.00085.01.png
# Saved denoised image: /content/output/HackSpace47.00056.01.png
# Saved denoised image: /content/output/BookOfMaking.00054.01.png
# Saved denoised image: /content/output/MagPi103.00046.02.png
# Saved denoised image: /content/output/MagPi100.00013.01.png
# Saved denoised image: /content/output/HackSpace51.00109.02.png
# Saved denoised image: /content/output/MagPi073.00100.02.png
# Saved denoised image: /content/output/Wireframe50.00017.02.png
# Saved denoised image: /content/output/Wireframe47.00054.01.png
# Saved denoised image: /content/output/HackSpace46.00080.01.png
# Saved denoised image: /content/output/MagPi061.00084.02.png
# Saved denoised image: /content/output/Wireframe47.00011.02.png
# Saved denoised image: /content/output/BookOfMaking.00053.01.png
# Saved denoised image: /content/output/MagPi100.00068.01.png
# Saved denoised image: /content/output/MagPi094.00087.02.png
# Saved denoised image: /content/output/MagPi056.00093.01.png
# Saved denoised image: /content/output/MagPi075.00055.01.png
# Saved denoised image: /content/output/MagPi068.00070.01.png
# Saved denoised image: /content/output/MagPi100.00061.02.png
# Saved denoised image: /content/output/MagPi067.00058.01.png
# Saved denoised image: /content/output/MagPi074.00027.02.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00045.01.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00215.01.png
# Saved denoised image: /content/output/MagPi056.00074.01.png
# Saved denoised image: /content/output/MagPi061.00016.02.png
# Saved denoised image: /content/output/Wireframe57.00016.02.png
# Saved denoised image: /content/output/MagPi113.00048.01.png
# Saved denoised image: /content/output/MagPi061.00074.01.png
# Saved denoised image: /content/output/Wireframe56.00108.02.png
# Saved denoised image: /content/output/scanner01_054.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00064.01.png
# Saved denoised image: /content/output/MagPi105.00024.02.png
# Saved denoised image: /content/output/MagPi051.00087.02.png
# Saved denoised image: /content/output/MagPi072.00071.01.png
# Saved denoised image: /content/output/MagPi112.00088.01.png
# Saved denoised image: /content/output/RaspberryPiCameraGuide.00017.02.png
# Saved denoised image: /content/output/HackSpace41.00013.02.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00193.02.png
# Saved denoised image: /content/output/MagPi075.00060.01.png
# Saved denoised image: /content/output/MagPi099.00072.02.png
# Saved denoised image: /content/output/scanner01_146.png
# Saved denoised image: /content/output/MagPi100.00045.01.png
# Saved denoised image: /content/output/MagPi086.00097.02.png
# Saved denoised image: /content/output/GetStartedArduino.00083.02.png
# Saved denoised image: /content/output/MagPi059.00018.01.png
# Saved denoised image: /content/output/MagPi101.00094.02.png
# Saved denoised image: /content/output/BookOfMaking.00159.01.png
# Saved denoised image: /content/output/MagPi061.00027.01.png
# Saved denoised image: /content/output/BookOfMaking.00120.02.png
# Saved denoised image: /content/output/MagPi101.00099.01.png
# Saved denoised image: /content/output/MagPi099.00037.01.png
# Saved denoised image: /content/output/HackSpace38.00084.01.png
# Saved denoised image: /content/output/BookOfMaking.00123.02.png
# Saved denoised image: /content/output/MagPi108.00077.01.png
# Saved denoised image: /content/output/Wireframe56.00049.02.png
# Saved denoised image: /content/output/MagPi057.00073.02.png
# Saved denoised image: /content/output/MagPi060.00058.02.png
# Saved denoised image: /content/output/RaspberryPiCameraGuide.00024.02.png
# Saved denoised image: /content/output/HackSpace50.00090.01.png
# Saved denoised image: /content/output/MagPi050.00045.01.png
# Saved denoised image: /content/output/MagPi048.00037.01.png
# Saved denoised image: /content/output/MagPi067.00048.01.png
# Saved denoised image: /content/output/HackSpace51.00066.02.png
# Saved denoised image: /content/output/MagPi066.00088.01.png
# Saved denoised image: /content/output/HackSpace38.00069.01.png
# Saved denoised image: /content/output/MagPi062.00004.02.png
# Saved denoised image: /content/output/WearableTechProjects.00153.01.png
# Saved denoised image: /content/output/MagPi074.00006.01.png
# Saved denoised image: /content/output/HackSpace41.00087.02.png
# Saved denoised image: /content/output/MagPi097.00059.02.png
# Saved denoised image: /content/output/MagPi097.00055.02.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00030.02.png
# Saved denoised image: /content/output/MagPi048.00004.02.png
# Saved denoised image: /content/output/Wireframe48.00082.01.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00018.01.png
# Saved denoised image: /content/output/MagPi108.00078.01.png
# Saved denoised image: /content/output/HackSpace36.00052.01.png
# Saved denoised image: /content/output/MagPi049.00033.01.png
# Saved denoised image: /content/output/HackSpace43.00057.01.png
# Saved denoised image: /content/output/HackSpace38.00063.02.png
# Saved denoised image: /content/output/scanner04_015.png
# Saved denoised image: /content/output/Wireframe53.00086.02.png
# Saved denoised image: /content/output/RaspberryPiBeginnersGuide4thEdition.00049.01.png
# Saved denoised image: /content/output/HackSpace45.00009.02.png
# Saved denoised image: /content/output/MagPi113.00068.02.png
# Saved denoised image: /content/output/MagPi103.00047.01.png
# Saved denoised image: /content/output/HackSpace37.00099.02.png
# Saved denoised image: /content/output/Wireframe53.00046.01.png
# Saved denoised image: /content/output/MagPi047.00076.01.png
# Saved denoised image: /content/output/MagPi072.00054.01.png
# Saved denoised image: /content/output/Wireframe50.00113.01.png
# Saved denoised image: /content/output/BookOfMaking.00150.01.png
# Saved denoised image: /content/output/MagPi079.00002.01.png
# Saved denoised image: /content/output/GetStartedArduino.00011.01.png
# Saved denoised image: /content/output/Wireframe53.00057.02.png
# Saved denoised image: /content/output/MagPi050.00093.02.png
# Saved denoised image: /content/output/MagPi089.00049.01.png
# Saved denoised image: /content/output/MagPi052.00004.01.png
# Saved denoised image: /content/output/CreateGraphicalUserInterfacesWithPython.00071.02.png
# Saved denoised image: /content/output/MagPi049.00018.01.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00100.02.png
# Saved denoised image: /content/output/Wireframe47.00102.02.png
# Saved denoised image: /content/output/HackSpace42.00023.02.png
# Saved denoised image: /content/output/MagPi074.00031.01.png
# Saved denoised image: /content/output/MagPi076.00068.01.png
# Saved denoised image: /content/output/MagPi089.00075.01.png
# Saved denoised image: /content/output/Wireframe51.00067.02.png
# Saved denoised image: /content/output/EssentialsAIYProjectsVoice.00028.02.png
# Saved denoised image: /content/output/MagPi092.00053.02.png
# Saved denoised image: /content/output/MagPi074.00004.02.png
# Saved denoised image: /content/output/MagPi049.00006.01.png
# Saved denoised image: /content/output/MagPi066.00055.01.png
# Saved denoised image: /content/output/MagPi074.00075.02.png
# Saved denoised image: /content/output/HackSpace40.00013.02.png
# Saved denoised image: /content/output/TheOfficialRaspberryPiHandbook2022.00141.02.png
# Saved denoised image: /content/output/MagPi049.00058.01.png
# Saved denoised image: /content/output/MagPi099.00052.01.png
# Saved denoised image: /content/output/Wireframe51.00047.01.png
# Saved denoised image: /content/output/MagPi099.00080.01.png
# Saved denoised image: /content/output/HackSpace44.00101.01.png
# Saved denoised image: /content/output/HackSpace41.00113.02.png
# Saved denoised image: /content/output/HackSpace36.00015.02.png
# Saved denoised image: /content/output/MagPi103.00021.01.png
# Saved denoised image: /content/output/MagPi056.00034.02.png
# Saved denoised image: /content/output/MagPi061.00096.01.png
# Saved denoised image: /content/output/MagPi077.00054.01.png
# Saved denoised image: /content/output/HackSpace42.00042.01.png
# Saved denoised image: /content/output/MagPi052.00019.02.png
# Saved denoised image: /content/output/EssentialsAIYProjectsVoice.00005.02.png
# Saved denoised image: /content/output/MagPi052.00025.02.png
# Saved denoised image: /content/output/Wireframe50.00044.02.png
# Saved denoised image: /content/output/MagPi048.00090.02.png
# Saved denoised image: /content/output/scanner01_161.png
# Saved denoised image: /content/output/Wireframe56.00003.01.png
# Saved denoised image: /content/output/GetStartedMicroPython.00137.01.png
# Saved denoised image: /content/output/HackSpace44.00110.01.png
# Saved denoised image: /content/output/Wireframe51.00049.01.png
# Saved denoised image: /content/output/HackSpace45.00056.02.png
# Saved denoised image: /content/output/MagPi095.00089.02.png
# Saved denoised image: /content/output/MagPi070.00072.02.png
# Saved denoised image: /content/output/MagPi079.00022.01.png
# Saved denoised image: /content/output/MagPi058.00030.01.png
# Saved denoised image: /content/output/HackSpace46.00092.01.png
# Saved denoised image: /content/output/MagPi098.00099.01.png
# Saved denoised image: /content/output/MagPi103.00011.02.png
# Saved denoised image: /content/output/MagPi100.00049.01.png
# Saved denoised image: /content/output/GetStartedArduino.00113.01.png
# Saved denoised image: /content/output/MagPi098.00023.01.png
# Saved denoised image: /content/output/BuildYourOwnFirstPersonShooterInUnity.00114.01.png
# Saved denoised image: /content/output/MagPi105.00042.02.png
# Saved denoised image: /content/output/MagPi073.00052.02.png
# Saved denoised image: /content/output/MagPi051.00040.02.png
# Saved denoised image: /content/output/MagPi089.00014.02.png
# Saved denoised image: /content/output/MagPi072.00057.02.png
# Saved denoised image: /content/output/scanner03_156.png
# Saved denoised image: /content/output/MagPi094.00024.01.png
# Saved denoised image: /content/output/MagPi070.00063.01.png
# Saved denoised image: /content/output/MagPi066.00004.02.png
# Saved denoised image: /content/output/HackSpace36.00115.01.png
# Saved denoised image: /content/output/MagPi108.00067.01.png
# Saved denoised image: /content/output/MagPi061.00064.01.png
# Saved denoised image: /content/output/MagPi057.00006.02.png
# Saved denoised image: /content/output/MagPi077.00077.02.png
# Saved denoised image: /content/output/MagPi077.00007.02.png

# %% [markdown]
# # 정답 csv 파일 생성

# %%
import os
import cv2
import csv
import numpy as np

folder_path = '/content/output'
output_file = 'output.csv'

# 폴더 내 이미지 파일 이름 목록을 가져오기
file_names = os.listdir(folder_path)
file_names.sort()

# CSV 파일을 작성하기 위해 오픈
with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Image File', 'Y Channel Value'])

    for file_name in file_names:
        # 이미지 로드
        image_path = os.path.join(folder_path, file_name)
        image = cv2.imread(image_path)

        # 이미지를 YUV 색 공간으로 변환
        image_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)

        # Y 채널 추출
        y_channel = image_yuv[:, :, 0]

        # Y 채널을 1차원 배열로 변환
        y_values = np.mean(y_channel.flatten())

        print(y_values)

        # 파일 이름과 Y 채널 값을 CSV 파일에 작성
        writer.writerow([file_name[:-4], y_values])

print('CSV file created successfully.')
# Out:
# 227.91037368774414
# 193.15660095214844
# 183.9034538269043
# 178.49835968017578
# 126.03963088989258
# 72.21139907836914
# 112.73012924194336
# 153.03966522216797
# 191.05475616455078
# 21.916126251220703
# 231.5547866821289
# 186.049560546875
# 220.12947845458984
# 231.01990509033203
# 186.28069305419922
# 143.3922348022461
# 131.76703643798828
# 75.75244140625
# 83.3723258972168
# 222.32677459716797
# 238.04832458496094
# 217.24547576904297
# 239.21669006347656
# 233.81790161132812
# 222.94137954711914
# 215.0599708557129
# 100.55659484863281
# 82.08529663085938
# 30.844390869140625
